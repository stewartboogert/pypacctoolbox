# %%
import pypacctoolbox
import sympy

# %% [markdown]
# ## Drift

# %%
d = pypacctoolbox.element.Drift("d",1)

# %%
d.hamiltonian
# Out:
# -sqrt(-p_x**2 - p_y**2 + (delta + 1/beta0)**2 - 1/(beta0**2*gamma0**2)) + delta/beta0

# %%
d.canonical_coords
# Out:
# [x, y, z]

# %%
d.canonical_momenta
# Out:
# [p_x, p_y, delta]

# %%
d.canonical_variables
# Out:
# [x, y, z, p_x, p_y, delta]

# %%
d.equations_of_motion()[5]
# Out:
# -(delta + 1/beta0)/sqrt(-p_x**2 - p_y**2 + (delta + 1/beta0)**2 - 1/(beta0**2*gamma0**2)) + 1/beta0

# %%
d.hamiltonian
# Out:
# -sqrt(-p_x**2 - p_y**2 + (delta + 1/beta0)**2 - 1/(beta0**2*gamma0**2)) + delta/beta0

# %%
x,y,z,p_x,p_y,delta = d.canonical_variables
beta0, gamma0 = d.relativistic_variables

# %%
print(d.taylor_coefficient(x,0,x,0))
print(d.taylor_coefficient(x,1,p_x,0))
print(d.taylor_coefficient(x,0,p_x,1))
print(d.taylor_coefficient(x,0,p_x,2))
print(d.taylor_coefficient(y,1,p_y,0))
print(d.taylor_coefficient(y,0,p_y,1))
print(d.taylor_coefficient(y,0,p_y,2))
print(d.taylor_coefficient(x,0,delta,1))
print(d.taylor_coefficient(x,0,delta,2))
# Out:
# -1
# 0
# 0
# 1
# 0
# 0
# 1
# 0
# -1 + beta0**(-2)

# %%
d.approximate_hamiltonian()
# Out:
# x x 0 0 -1
# x x 0 1 0
# x x 0 2 0
# x x 1 1 0
# x x 1 2 0
# x x 2 2 0
# x y 0 0 -1
# x y 0 1 0
# x y 0 2 0
# x y 1 1 0
# x y 1 2 0
# x y 2 2 0
# x z 0 0 -1
# x z 0 1 0
# x z 0 2 0
# x z 1 1 0
# x z 1 2 0
# x z 2 2 0
# x p_x 0 0 -1
# x p_x 0 1 0
# x p_x 0 2 1
# x p_x 1 1 0
# x p_x 1 2 0
# x p_x 2 2 0
# x p_y 0 0 -1
# x p_y 0 1 0
# x p_y 0 2 1
# x p_y 1 1 0
# x p_y 1 2 0
# x p_y 2 2 0
# x delta 0 0 -1
# x delta 0 1 0
# x delta 0 2 -1 + beta0**(-2)
# x delta 1 1 0
# x delta 1 2 0
# x delta 2 2 0
# y y 0 0 -1
# y y 0 1 0
# y y 0 2 0
# y y 1 1 0
# y y 1 2 0
# y y 2 2 0
# y z 0 0 -1
# y z 0 1 0
# y z 0 2 0
# y z 1 1 0
# y z 1 2 0
# y z 2 2 0
# y p_x 0 0 -1
# y p_x 0 1 0
# y p_x 0 2 1
# y p_x 1 1 0
# y p_x 1 2 0
# y p_x 2 2 0
# y p_y 0 0 -1
# y p_y 0 1 0
# y p_y 0 2 1
# y p_y 1 1 0
# y p_y 1 2 0
# y p_y 2 2 0
# y delta 0 0 -1
# y delta 0 1 0
# y delta 0 2 -1 + beta0**(-2)
# y delta 1 1 0
# y delta 1 2 0
# y delta 2 2 0
# z z 0 0 -1
# z z 0 1 0
# z z 0 2 0
# z z 1 1 0
# z z 1 2 0
# ...

# %% [markdown]
# # Quadrupole

# %%
l = sympy.Symbol("l")
k1 = sympy.Symbol("k1")
d = pypacctoolbox.element.Quadrupole("q",1,k1)

# %%
d.hamiltonian
# Out:
# k1*(x**2 - y**2)/2 - sqrt(-p_x**2 - p_y**2 + (delta + 1/beta0)**2 - 1/(beta0**2*gamma0**2)) + delta/beta0

# %%
d.equations_of_motion()
# Out:
# [k1*x,
#  -k1*y,
#  0,
#  p_x/sqrt(-p_x**2 - p_y**2 + (delta + 1/beta0)**2 - 1/(beta0**2*gamma0**2)),
#  p_y/sqrt(-p_x**2 - p_y**2 + (delta + 1/beta0)**2 - 1/(beta0**2*gamma0**2)),
#  -(delta + 1/beta0)/sqrt(-p_x**2 - p_y**2 + (delta + 1/beta0)**2 - 1/(beta0**2*gamma0**2)) + 1/beta0]

# %%
d.approximate_hamiltonian()
# Out:
# x x 0 0 -1
# x x 0 1 0
# x x 1 0 0
# x x 1 1 k1
# x x 2 0 k1
# x x 2 1 0
# x y 1 0 0
# x y 1 1 0
# x y 2 0 k1
# x y 2 1 0
# x z 2 0 k1
# x z 2 1 0
# y x 0 0 -1
# y x 0 1 0
# y x 1 0 0
# y x 1 1 0
# y x 2 0 -k1
# y x 2 1 0
# y y 1 0 0
# y y 1 1 -k1
# y y 2 0 -k1
# y y 2 1 0
# y z 2 0 -k1
# y z 2 1 0
# z x 0 0 -1
# z x 0 1 0
# z x 1 0 0
# z x 1 1 0
# z x 2 0 0
# z x 2 1 0
# z y 1 0 0
# z y 1 1 0
# z y 2 0 0
# z y 2 1 0
# z z 2 0 0
# z z 2 1 0
# p_x x 0 0 -1
# p_x x 0 1 0
# p_x x 1 0 0
# p_x x 1 1 0
# p_x x 2 0 1
# p_x x 2 1 0
# p_x y 1 0 0
# p_x y 1 1 0
# p_x y 2 0 1
# p_x y 2 1 0
# p_x z 2 0 1
# p_x z 2 1 0
# p_y x 0 0 -1
# p_y x 0 1 0
# p_y x 1 0 0
# p_y x 1 1 0
# p_y x 2 0 1
# p_y x 2 1 0
# p_y y 1 0 0
# p_y y 1 1 0
# p_y y 2 0 1
# p_y y 2 1 0
# p_y z 2 0 1
# p_y z 2 1 0
# delta x 0 0 -1
# delta x 0 1 0
# delta x 1 0 0
# delta x 1 1 0
# delta x 2 0 -1 + beta0**(-2)
# delta x 2 1 0
# delta y 1 0 0
# delta y 1 1 0
# delta y 2 0 -1 + beta0**(-2)
# delta y 2 1 0
# ...
