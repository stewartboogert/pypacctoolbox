# %%
import pypacctoolbox

# %%
i1 = pypacctoolbox.math.MultiIndex([1,2,3])
i2 = pypacctoolbox.math.MultiIndex([5,6,7])

# %%
i1.factorial()
# Out:
# 12

# %%
i1+i2
# Out:
# [6, 8, 10]

# %%
i1.norm()
# Out:
# 6
